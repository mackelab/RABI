# %%
import svgutils.transform as sg
import sys 

from IPython.display import SVG,display

#create new SVG figure
fig = sg.SVGFigure(width="9cm", height="9cm")



# load matpotlib-generated figures
fig1 = sg.fromfile('x.svg')
fig2 = sg.fromfile('delta.svg')
fig3 = sg.fromfile("x_tilde.svg")
fig4 = sg.fromfile("post.svg")
fig5 = sg.fromfile("adversarial_post.svg")
fig6 = sg.fromfile("rob_adversarial_post.svg")
fig7 = sg.fromfile("x_pred1.svg")
fig8 = sg.fromfile("x_pred2.svg")
fig9 = sg.fromfile("x_tilde_pred1.svg")
fig10 = sg.fromfile("x_tilde_pred2.svg")
fig11 = sg.fromfile("rob_x_pred1.svg")
fig12 = sg.fromfile("rob_x_pred2.svg")


txt_fig1 = sg.fromfile("x_o_text.svg").getroot()
txt_fig2 = sg.fromfile("adversarial_pert_text.svg").getroot()
txt_fig3 = sg.fromfile("x_tilde_text.svg").getroot()
txt_fig4 = sg.fromfile("inference.svg").getroot()
txt_fig5 = sg.fromfile("predictive.svg").getroot()

arrow = sg.fromfile("arrow.svg").getroot()
arrow2 = sg.fromfile("strange_arrow.svg").getroot()
shield = sg.fromfile("shield.svg").getroot()
shield.scale_xy(0.022,0.022)

# get the plot objects
plot1 = fig1.getroot()
plot2 = fig2.getroot()
plot3 = fig3.getroot()
plot4 = fig4.getroot()
plot5 = fig5.getroot()
plot6 = fig6.getroot()
plot7 = fig7.getroot()
plot8 = fig8.getroot()
plot9 = fig9.getroot()
plot10 = fig10.getroot()
plot11 = fig11.getroot()
plot12 = fig12.getroot()

plots = [plot1,plot2,plot3,plot4,plot5,plot6,plot7,plot8,plot9,plot10,plot11,plot12, arrow, arrow2]
for p in plots:
    p.scale_xy(0.5,0.5)

plot1.moveto(-15,30)
#plot1.scale_xy(0.8, 0.8)
plot2.moveto(-15,130)
#plot2.scale_xy(0.8, 0.8)
plot3.moveto(-15,230)
#plot3.scale_xy(0.8, 0.8)
plot4.moveto(150, 10)
plot5.moveto(150,110)
plot6.moveto(150,210)
plot7.moveto(240,30)
plot8.moveto(240,70)
plot9.moveto(240,125)
plot10.moveto(240,165)
plot11.moveto(240,230)
plot12.moveto(240,270)




txt_fig1.moveto(-25,-25)
arrow.moveto(120, 65)
arrow2.moveto(120, 153)
txt_fig2.moveto(-11,80)
txt_fig3.moveto(-11,180)
txt_fig4.moveto(140,-40)
txt_fig5.moveto(235,-40)
shield.moveto(150,291)

txt1 = sg.TextElement(50,127, "+", size=25, font="Arial")
txt2 = sg.TextElement(50,217, "=", size=20, weight="bold", font="Arial")
txt3 = sg.TextElement(132,75, "NPE", size=9, weight="bold", font="Arial")
txt4 = sg.TextElement(132,175, "NPE", size=9, weight="bold", font="Arial")
txt5 = sg.TextElement(128,300, "NPE-", size=9, weight="bold", font="Arial")


# append plots and labels to figure
fig.append([plot1, plot2, plot3, plot4, plot5,plot6,txt_fig1,txt_fig2,txt_fig3, txt_fig4,txt_fig5,arrow, arrow2, plot7, plot8,plot9,plot10,plot11,plot12, shield])
fig.append([txt1,txt2,txt3,txt4,txt5])


# save generated SVG files
fig.save("fig1_final.svg")


svg = SVG(filename='fig1_final.svg')
svg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import svgutils.transform as sg
#       2 import sys
#       4 from IPython.display import SVG,display
#
# ModuleNotFoundError: No module named 'svgutils'
